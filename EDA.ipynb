# %% [markdown]
# 商品字段的主键

# %%
data_product = data[['product_id','category_id','category_code','brand']]
data_product
# Out:
#           product_id          category_id  \
# 0           44600062  2103807459595387724
# 1            3900821  2053013552326770905
# 2           17200506  2053013559792632471
# 3            1307067  2053013558920217191
# 4            1004237  2053013555631882655
# ...              ...                  ...
# 42448759     2300275  2053013560530830019
# 42448760    10800172  2053013554994348409
# 42448761     5701038  2053013553970938175
# 42448762    21407424  2053013561579406073
# 42448763    13300120  2053013557166998015
#
#                                 category_code      brand
# 0                                         NaN   shiseido
# 1         appliances.environment.water_heater       aqua
# 2                  furniture.living_room.sofa        NaN
# 3                          computers.notebook     lenovo
# 4                      electronics.smartphone      apple
# ...                                       ...        ...
# ...

# %%
data_product.groupby('product_id').nunique()
# Out:
#             category_id  category_code  brand
# product_id
# 1000978               1              1      1
# 1001588               1              1      1
# 1001606               1              1      1
# 1002042               1              1      1
# 1002062               1              1      1
# ...                 ...            ...    ...
# 60500006              1              1      1
# 60500007              1              1      1
# 60500008              1              1      0
# 60500009              1              1      0
# 60500010              1              1      1
#
# [166794 rows x 3 columns]

# %% [markdown]
# # 商品基础

# %%
# sku
data['product_id'].nunique()
# Out:
# 166794

# %%
# 
data.query('category_id == 2053013552326770905')
# Out:
#                        event_time event_type  product_id          category_id  \
# 1         2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 12        2019-10-01 00:00:13 UTC       view     3900746  2053013552326770905
# 27        2019-10-01 00:00:25 UTC       view     3900990  2053013552326770905
# 38        2019-10-01 00:00:31 UTC       view     3900746  2053013552326770905
# 71        2019-10-01 00:01:00 UTC       view     3900930  2053013552326770905
# ...                           ...        ...         ...                  ...
# 42439091  2019-10-31 22:41:28 UTC       view     3900686  2053013552326770905
# 42446629  2019-10-31 23:42:45 UTC       view     3900815  2053013552326770905
# 42447094  2019-10-31 23:46:30 UTC       view     3900968  2053013552326770905
# 42448574  2019-10-31 23:58:39 UTC       view     3901174  2053013552326770905
# 42448675  2019-10-31 23:59:23 UTC       view     3901090  2053013552326770905
#
# ...

# %%
data.query('brand == "lenovo"')['category_code'].unique()
# Out:
# ['computers.notebook', 'computers.desktop', 'accessories.bag', 'electronics.tablet', 'computers.peripherals.mouse', ..., 'computers.components.memory', 'electronics.audio.headphone', 'computers.peripherals.monitor', 'computers.components.hdd', NaN]
# Length: 11
# Categories (126, object): ['accessories.bag', 'accessories.umbrella', 'accessories.wallet', 'apparel.belt', ..., 'sport.snowboard', 'sport.tennis', 'sport.trainer', 'stationery.cartrige']
