# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# 让画图内置
# %matplotlib inline
# 设置画布大小
plt.rcParams["figure.figsize"] = (10, 6)


# 忽略版本号之类的warnings
import warnings
warnings.filterwarnings('ignore')
import os
from datetime import date

# %% [markdown]
# # 数据导入

# %%
# 导入数据
# original_data = pd.read_csv('data\processed_data.csv')
# data = original_data.copy()
# data.shape

# %%
# 导入数据
data = pd.read_csv('data\processed_data.csv')
data.shape
# Out:
# (42413557, 11)

# %%
data['event_time'] = pd.to_datetime(data['event_time'])
data['category_code'] = data['category_code'].astype('category')
data['brand'] = data['brand'].astype('category')

data['event_day'] = data['event_time'].dt.date
data['event_hour'] = data['event_time'].dt.hour

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42413557 entries, 0 to 42413556
# Data columns (total 13 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     datetime64[ns]
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  category
#  5   brand          category
#  6   price          float64
#  7   user_id        int64
#  8   category       object
#  9   sub_category   object
#  10  product_name   object
#  11  event_day      object
#  12  event_hour     int32
# dtypes: category(2), datetime64[ns](1), float64(1), int32(1), int64(3), object(5)
# memory usage: 3.4+ GB

# %%
data.head()
# Out:
#            event_time event_type  product_id          category_id  \
# 0 2019-10-01 00:00:00       view    44600062  2103807459595387724
# 1 2019-10-01 00:00:00       view     3900821  2053013552326770905
# 2 2019-10-01 00:00:01       view    17200506  2053013559792632471
# 3 2019-10-01 00:00:01       view     1307067  2053013558920217191
# 4 2019-10-01 00:00:04       view     1004237  2053013555631882655
#
#                          category_code     brand   price    user_id  \
# 0                                  NaN  shiseido   35.79  541312140
# 1  appliances.environment.water_heater      aqua   33.20  554748717
# 2           furniture.living_room.sofa       NaN  543.10  519107250
# 3                   computers.notebook    lenovo  251.74  550050854
# 4               electronics.smartphone     apple 1081.98  535871217
#
#       category sub_category  product_name   event_day  event_hour
# 0          NaN          NaN           NaN  2019-10-01           0
# 1   appliances  environment  water_heater  2019-10-01           0
# 2    furniture  living_room          sofa  2019-10-01           0
# 3    computers     notebook      notebook  2019-10-01           0
# 4  electronics   smartphone    smartphone  2019-10-01           0

# %% [markdown]
# # 流量指标
# - PV UV

# %%
view_info  = data.query('event_type == "view"')
puv = view_info.groupby('event_type').agg(PV = ('user_id','count'),
              UV = ('user_id','nunique'))
puv['PUV'] = puv['PV'] / puv['UV']
puv
# Out:
#                   PV       UV   PUV
# event_type
# view        40772341  3022130 13.49

# %% [markdown]
# ### 分日

# %%
view_info_byday = view_info.groupby(['event_day']).agg(PV = ('user_id','count'),
              UV = ('user_id','nunique'))
view_info_byday['puv'] = round(view_info_byday['PV']/view_info_byday['UV'],2)
view_info_byday
# Out:
#                  PV      UV  puv
# event_day
# 2019-10-01  1208165  190158 6.35
# 2019-10-02  1154436  184955 6.24
# 2019-10-03  1088577  170655 6.38
# 2019-10-04  1346162  209393 6.43
# 2019-10-05  1271176  194949 6.52
# 2019-10-06  1263876  193194 6.54
# 2019-10-07  1160929  186939 6.21
# 2019-10-08  1328893  221194 6.01
# 2019-10-09  1306089  214133 6.10
# 2019-10-10  1242891  205307 6.05
# 2019-10-11  1447502  230514 6.28
# 2019-10-12  1433723  208349 6.88
# 2019-10-13  1584488  225923 7.01
# 2019-10-14  1381286  209077 6.61
# 2019-10-15  1466116  230118 6.37
# 2019-10-16  1445559  230184 6.28
# 2019-10-17  1338173  208456 6.42
# 2019-10-18  1415597  229444 6.17
# 2019-10-19  1384908  217897 6.36
# 2019-10-20  1443869  231826 6.23
# 2019-10-21  1343132  225238 5.96
# 2019-10-22  1354156  223369 6.06
# 2019-10-23  1319648  219081 6.02
# 2019-10-24  1256473  206920 6.07
# 2019-10-25  1374227  223233 6.16
# 2019-10-26  1289569  202100 6.38
# 2019-10-27  1330652  201332 6.61
# 2019-10-28  1221695  195544 6.25
# 2019-10-29  1189864  193148 6.16
# 2019-10-30  1172126  191946 6.11
# 2019-10-31  1208384  198544 6.09

# %%
view_info_byday.describe()
# Out:
#               PV        UV   puv
# count      31.00     31.00 31.00
# mean  1315236.81 208810.32  6.30
# std    111084.61  16233.32  0.25
# min   1088577.00 170655.00  5.96
# 25%   1232293.00 195246.50  6.11
# 50%   1328893.00 208456.00  6.25
# 75%   1383097.00 223301.00  6.40
# max   1584488.00 231826.00  7.01

# %% [markdown]
# ### 分时

# %%
view_info_by_hour = view_info.groupby(['event_hour']).agg(PV = ('user_id','count'),
              UV = ('user_id','nunique'))
view_info_by_hour
# Out:
#                  PV      UV
# event_hour
# 0            299740   59584
# 1            545513  116376
# 2           1036894  209100
# 3           1485498  290737
# 4           1826073  351996
# 5           2020202  387131
# 6           2154159  413004
# 7           2217399  426678
# 8           2267568  432146
# 9           2228945  421753
# 10          2181257  413410
# 11          2086570  398675
# 12          2040518  393493
# 13          2263309  419289
# 14          2590043  442995
# 15          2892301  459169
# 16          2971773  445817
# 17          2663078  384366
# 18          2069058  311609
# 19          1303958  191347
# 20           722698  107685
# 21           425065   64531
# 22           264757   41243
# 23           215965   37080

# %% [markdown]
# # 销售
# - 下单数 gmv 客单价
# - order_info

# %%
# 订单数 gmv
order_info  = data.query('event_type == "purchase"')
temp = order_info.groupby('event_type').agg(order_num = ('user_id','count'),
                                    gmv = ('price','sum'),
                                    ATV = ('price','mean'),
                                    order_user_num = ('user_id','nunique')
                                    )
temp['avg_user_value'] = temp['gmv']/temp['order_user_num']
temp['avg_user_order_num'] = temp['order_num']/temp['order_user_num']
temp
# Out:
#             order_num          gmv    ATV  order_user_num  avg_user_value  \
# event_type
# purchase       742773 229933212.63 309.56          347118          662.41
#
#             avg_user_order_num
# event_type
# purchase                  2.14

# %% [markdown]
# ### 分日

# %%
order_info_byday= order_info.groupby('event_day').agg(order_num = ('user_id','count'),
                                    gmv = ('price','sum'),
                                    ATV = ('price','mean'),
                                    order_user_num = ('user_id','nunique'))
order_info_byday['avg_user_value'] = order_info_byday['gmv']/order_info_byday['order_user_num']
order_info_byday['avg_user_order_num'] = order_info_byday['order_num']/order_info_byday['order_user_num']
order_info_byday
# Out:
#             order_num        gmv    ATV  order_user_num  avg_user_value  \
# event_day
# 2019-10-01      19305 6275579.06 325.08           14064          446.22
# 2019-10-02      19469 6213628.53 319.15           13894          447.22
# 2019-10-03      19255 6233782.98 323.75           13722          454.29
# 2019-10-04      27039 8623058.19 318.91           19214          448.79
# 2019-10-05      23492 7341094.46 312.49           16734          438.69
# 2019-10-06      22169 6737258.17 303.90           16096          418.57
# 2019-10-07      21378 6348189.06 296.95           15438          411.21
# 2019-10-08      23071 6819701.26 295.60           16590          411.07
# 2019-10-09      22747 6855326.05 301.37           16417          417.57
# 2019-10-10      21992 6665413.21 303.08           15959          417.66
# 2019-10-11      26224 7716208.55 294.24           18818          410.04
# 2019-10-12      25373 7307691.57 288.01           18374          397.72
# 2019-10-13      29561 8457606.49 286.11           21320          396.70
# 2019-10-14      28405 9356691.65 329.40           19388          482.60
# 2019-10-15      26371 8652872.26 328.12           18582          465.66
# 2019-10-16      31393 9747164.72 310.49           21993          443.19
# 2019-10-17      28317 9026019.07 318.75           19395          465.38
# 2019-10-18      25849 8154781.53 315.48           18385          443.56
# 2019-10-19      24657 7562479.36 306.71           17898          422.53
# 2019-10-20      25097 7515168.65 299.44           18195          413.03
# 2019-10-21      25165 7862143.64 312.42           18344          428.59
# 2019-10-22      25383 7913671.44 311.77           18290          432.68
# 2019-10-23      24730 7614084.79 307.89           17891          425.58
# 2019-10-24      23999 7470344.60 311.28           17294          431.96
# 2019-10-25      23883 7235218.34 302.94           17200          420.65
# 2019-10-26      22653 6917602.84 305.37           16513          418.92
# 2019-10-27      23401 7197520.64 307.57           16921          425.36
# 2019-10-28      21111 6591445.12 312.23           15315          430.39
# 2019-10-29      20372 6432162.00 315.74           14765          435.64
# 2019-10-30      20815 6633882.15 318.71           15158          437.65
# 2019-10-31      20097 6455422.25 321.21           14827          435.38
#
#             avg_user_order_num
# event_day
# 2019-10-01                1.37
# 2019-10-02                1.40
# 2019-10-03                1.40
# 2019-10-04                1.41
# 2019-10-05                1.40
# 2019-10-06                1.38
# 2019-10-07                1.38
# 2019-10-08                1.39
# 2019-10-09                1.39
# 2019-10-10                1.38
# 2019-10-11                1.39
# 2019-10-12                1.38
# 2019-10-13                1.39
# 2019-10-14                1.47
# 2019-10-15                1.42
# 2019-10-16                1.43
# 2019-10-17                1.46
# 2019-10-18                1.41
# 2019-10-19                1.38
# 2019-10-20                1.38
# 2019-10-21                1.37
# 2019-10-22                1.39
# 2019-10-23                1.38
# 2019-10-24                1.39
# 2019-10-25                1.39
# 2019-10-26                1.37
# 2019-10-27                1.38
# 2019-10-28                1.38
# 2019-10-29                1.38
# 2019-10-30                1.37
# 2019-10-31                1.36

# %%
order_info_byday.describe()
# Out:
#        order_num        gmv    ATV  order_user_num  avg_user_value  \
# count      31.00      31.00  31.00           31.00           31.00
# mean    23960.42 7417200.41 309.81        17193.35          431.44
# std      3083.45  957899.74  11.09         2042.37           19.65
# min     19255.00 6213628.53 286.11        13722.00          396.70
# 25%     21685.00 6649647.68 303.01        15698.50          418.11
# 50%     23883.00 7307691.57 311.28        17200.00          430.39
# 75%     25616.00 7887907.54 318.73        18379.50          443.38
# max     31393.00 9747164.72 329.40        21993.00          482.60
#
#        avg_user_order_num
# count               31.00
# mean                 1.39
# std                  0.02
# min                  1.36
# 25%                  1.38
# 50%                  1.39
# 75%                  1.40
# max                  1.47

# %% [markdown]
# ### 分时

# %%
order_info_byhour= order_info.groupby('event_hour').agg(order_num = ('user_id','count'),
                                    gmv = ('price','sum'))
order_info_byhour
# Out:
#             order_num         gmv
# event_hour
# 0                2949   980317.85
# 1                5526  1577532.87
# 2               13968  3873027.44
# 3               29632  8696837.45
# 4               41143 12064072.73
# 5               48068 14398553.24
# 6               52002 15808753.76
# 7               53404 16338607.12
# 8               55195 17058580.92
# 9               55182 17551669.73
# 10              51902 16361933.71
# 11              47311 15082588.07
# 12              41840 13238529.07
# 13              39135 12363944.23
# 14              37363 11476514.59
# 15              37632 11039895.72
# 16              35772 10636257.46
# 17              30872  9395005.91
# 18              24321  7968696.06
# 19              16747  5761335.06
# 20               9892  3504661.41
# 21               6278  2350810.75
# 22               3837  1409146.30
# 23               2802   995941.18
